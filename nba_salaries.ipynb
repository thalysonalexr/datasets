# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/icd-ufmg/data/master/nba_salaries.csv')

# %%
df
# Out:
#                PLAYER POSITION                TEAM     SALARY
# 0        Paul Millsap       PF       Atlanta Hawks  18.671659
# 1          Al Horford        C       Atlanta Hawks  12.000000
# 2      Tiago Splitter        C       Atlanta Hawks   9.756250
# 3         Jeff Teague       PG       Atlanta Hawks   8.000000
# 4         Kyle Korver       SG       Atlanta Hawks   5.746479
# 5     Thabo Sefolosha       SF       Atlanta Hawks   4.000000
# 6          Mike Scott       PF       Atlanta Hawks   3.333333
# 7       Kent Bazemore       SF       Atlanta Hawks   2.000000
# 8     Dennis Schroder       PG       Atlanta Hawks   1.763400
# 9    Tim Hardaway Jr.       SG       Atlanta Hawks   1.304520
# 10     Walter Tavares        C       Atlanta Hawks   1.000000
# 11   Jason Richardson       SG       Atlanta Hawks   0.947276
# 12    Lamar Patterson       SG       Atlanta Hawks   0.525093
# 13    Terran Petteway       SG       Atlanta Hawks   0.525093
# ...

# %%
# read file pass count in parameter or view the first five items
df.head(2)
# Out:
#          PLAYER POSITION           TEAM     SALARY
# 0  Paul Millsap       PF  Atlanta Hawks  18.671659
# 1    Al Horford        C  Atlanta Hawks  12.000000

# %%
# information in all columns
df.describe()
# Out:
#            SALARY
# count  417.000000
# mean     5.074814
# std      5.221437
# min      0.030888
# 25%      1.270964
# 50%      3.000000
# 75%      7.000000
# max     25.000000

# %%
# get a type data (columns)
df.dtypes
# Out:
# PLAYER       object
# POSITION     object
# TEAM         object
# SALARY      float64
# dtype: object

# %%
# count lines and columns
df.shape
# Out:
# (417, 4)

# %%
# rename a columns
df.columns = [
    'JOGADOR',
    'POSIÇÃO',
    'TIME',
    'SALÁRIO'
]

df.head(1)
# Out:
#         JOGADOR POSIÇÃO           TIME    SALÁRIO
# 0  Paul Millsap      PF  Atlanta Hawks  18.671659

# %%
# get a null values
df[df['JOGADOR'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [JOGADOR, POSIÇÃO, TIME, SALÁRIO]
# Index: []

# %%
# group a values in column
df['POSIÇÃO'].value_counts()
# Out:
# SG    96
# PG    85
# PF    85
# SF    82
# C     69
# Name: POSIÇÃO, dtype: int64

# %% [markdown]
# # Visualizar dados

# %%
df['POSIÇÃO'].value_counts().plot()

# %%
df['POSIÇÃO'].value_counts().head(10).plot(kind='bar')

# %%
# maior salário entre os ARMADORES

df[(df['SALÁRIO'] == df['SALÁRIO'].max()) & (df['POSIÇÃO'] == 'SF')]
# Out:
# SALÁRIO    25.0
# Name: 0.25, dtype: float64

# %%
df['SALÁRIO'].value_counts().head(10).plot(kind='bar')
